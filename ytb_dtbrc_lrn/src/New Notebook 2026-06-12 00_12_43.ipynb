# %%
data = [("Alice", 25), ("Bob", 30)]
col_name = ["name", "age"]
df = spark.createDataFrame(data, col_name)
df.write.mode("overwrite").format("delta").saveAsTable("youtube_dev.silver.earthquake_data")
